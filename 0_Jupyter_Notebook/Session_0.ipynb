# %% [markdown]
# 1. Hello World

# %%
print("Hello world")
print(" This is our session 0")
# Out:
# Hello world
#  This is our session 0

# %% [markdown]
# 2. Variable & Data Type

# %%
name = "Shawon"
age = 20
height = 5.9

print(name, age, height)
# Out:
# Shawon 20 5.9

# %% [markdown]
# 3. Take input

# %%
name = input()
print("Your name is ", name)
# Out:
# Medha
# Your name is  Medha

# %% [markdown]
# 4. If-Else Condition

# %%
age = int(input("Enter you age"))
if age >= 18:
    print("Adult")
else:
    print("Kids")
# Out:
# Enter you age19
# Adult

# %% [markdown]
# 5. Loops - For and While

# %%
i = 0
while i<5:
  print(i)
  i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# 6. Functions

# %%
def greet(name):
  return "Hello " + name

print(greet("Shakib"))
# Out:
# Hello Shakib

# %% [markdown]
# 7. List

# %%
Fruit = ["Mango", "Apple", "Litchi"]
print(Fruit)
Fruit.append("Banana")
print(Fruit.count("Mango"))
Fruit
# Out:
# ['Mango', 'Apple', 'Litchi']
# 1
# ['Mango', 'Apple', 'Litchi', 'Banana']

# %% [markdown]
# 8. Dictionary

# %%
student = {
    "name": "Mashura",
    "Age" : 20,
    "Height": 5.9
}

student['name']
# Out:
# 'Mashura'

# %% [markdown]
# 9. Simple Calculator

# %%
print("Simple Calculator")

# Function to add two numbers
def add(x, y):
    return x + y

# Function to subtract two numbers
def subtract(x, y):
    return x - y

# Function to multiply two numbers
def multiply(x, y):
    return x * y

# Function to divide two numbers
def divide(x, y):
    if y == 0:
        return "Error! Division by zero."
    return x / y

# Example calculation without user input
num1 = 10
operation = '+'
num2 = 5

if operation == '+':
    result = add(num1, num2)
elif operation == '-':
    result = subtract(num1, num2)
elif operation == '*':
    result = multiply(num1, num2)
elif operation == '/':
    result = divide(num1, num2)
else:
    result = "Invalid operation."

print(f"{num1} {operation} {num2} = {result}")

# %% [markdown]
# 10. Check Even or Odd

# %%
num = int(input("Enter an integer to check if it's even or odd: "))
if num % 2 == 0:
    print(f"{num} is an even number.")
else:
    print(f"{num} is an odd number.")

# %%
name = input("Enter Your name")
print("Your name is: ",name)
# Out:
# Enter Your namesayed
# Your name is:  sayed

# %%
age = int(input("Enter Your age"))
if age >= 18:
  print("Adult")
else:
  print("Kids")
# Out:
# Enter Your age12
# Kids

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0;
while i < 5:
  print(i)
  i += 1;
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def greet(name):
  return "Hello " + name

greet("sayed")
# Out:
# 'Hello sayed'

# %%
fruit = ["Mango", "litchi", "Mango"]
fruit.clear()
fruit
# Out:
# []

# %%
student  = {
    "name": "Abdullah",
    "Age": 20,
    "Height":5.9
}

print(student["name"])
# Out:
# Abdullah
